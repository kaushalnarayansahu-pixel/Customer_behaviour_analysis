# %%
import pandas as pd

df = pd.read_csv('/customer_shopping_behavior.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1106/2929142059.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/customer_shopping_behavior.csv')
#       4
#       5 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/customer_shopping_behavior.csv'

# %%
len(df)
# Out:
# 5050

# %%
df.shape
# Out:
# (5050, 17)

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  5050.000000  5050.000000            4494.000000    4449.000000
# mean   2519.570891    44.150495             144.765236       3.668195
# std    1470.402964    15.282328             275.590101       0.865357
# min       1.000000    18.000000              10.120000       1.000000
# 25%    1252.250000    31.000000              41.000000       3.000000
# 50%    2499.500000    44.000000              65.000000       3.700000
# 75%    3740.750000    57.000000              89.000000       4.400000
# max    5099.000000    70.000000            1499.760000       5.000000
#
#        Previous Purchases
# count         4502.000000
# mean            25.221901
# std             14.521635
# min              0.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   5050.000000  5050.000000   5050           5050      5050
# unique          NaN          NaN      3             30         5
# top             NaN          NaN   Male          Shirt  Clothing
# freq            NaN          NaN   3018            320      2130
# mean    2519.570891    44.150495    NaN            NaN       NaN
# std     1470.402964    15.282328    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%     1252.250000    31.000000    NaN            NaN       NaN
# 50%     2499.500000    44.000000    NaN            NaN       NaN
# 75%     3740.750000    57.000000    NaN            NaN       NaN
# max     5099.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# count             4494.000000      5050  4680   5050    5050    4449.000000
# unique                    NaN        54     4     25       5            NaN
# top                       NaN  New York     M  Black  Spring            NaN
# freq                      NaN       337  1981    404    1280            NaN
# mean               144.765236       NaN   NaN    NaN     NaN       3.668195
# std                275.590101       NaN   NaN    NaN     NaN       0.865357
# min                 10.120000       NaN   NaN    NaN     NaN       1.000000
# 25%                 41.000000       NaN   NaN    NaN     NaN       3.000000
# 50%                 65.000000       NaN   NaN    NaN     NaN       3.700000
# 75%                 89.000000       NaN   NaN    NaN     NaN       4.400000
# max               1499.760000       NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status Shipping Type Discount Applied  Previous Purchases  \
# count                 5050          5050             5050         4502.000000
# unique                   2             6                2                 NaN
# top                     No      Standard               No                 NaN
# freq                  3462          1213             2789                 NaN
# mean                   NaN           NaN              NaN           25.221901
# std                    NaN           NaN              NaN           14.521635
# min                    NaN           NaN              NaN            0.000000
# 25%                    NaN           NaN              NaN           13.000000
# 50%                    NaN           NaN              NaN           25.000000
# 75%                    NaN           NaN              NaN           38.000000
# max                    NaN           NaN              NaN           50.000000
#
#        Payment Method Frequency of Purchases
# count            5050                   5050
# unique              6                      7
# top       Credit Card                Monthly
# freq              954                    946
# mean              NaN                    NaN
# std               NaN                    NaN
# min               NaN                    NaN
# 25%               NaN                    NaN
# 50%               NaN                    NaN
# 75%               NaN                    NaN
# max               NaN                    NaN

# %%
import pandas as pd

df = pd.read_csv('/content/customer_shopping_behavior.csv')

df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             5050 non-null   int64
#  1   Age                     5050 non-null   int64
#  2   Gender                  5050 non-null   object
#  3   Item Purchased          5050 non-null   object
#  4   Category                5050 non-null   object
#  5   Purchase Amount (USD)   4494 non-null   float64
#  6   Location                5050 non-null   object
#  7   Size                    4680 non-null   object
#  8   Color                   5050 non-null   object
#  9   Season                  5050 non-null   object
#  10  Review Rating           4449 non-null   float64
#  11  Subscription Status     5050 non-null   object
#  12  Shipping Type           5050 non-null   object
#  13  Discount Applied        5050 non-null   object
#  14  Previous Purchases      4502 non-null   float64
#  15  Payment Method          5050 non-null   object
#  16  Frequency of Purchases  5050 non-null   object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 670.8+ KB

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# ## data cleaning

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories               [Sunglasses, Gloves, Jewelry, Hat, Handbag, Phone, Backpack, Belt, Bag, Headphones, Scarf, Watch, Shirt, Shoes, Laptop]
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone, Pants, Socks, Jeans, Bag, Blouse, Skirt, Sweater, Watch, Laptop, Dress, Headphones]
# Electronics                                                                                 [Laptop, Phone, Watch, Bag, Shoes, Shirt, Headphones]
# Footwear                                                                                                        [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                                                                          [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
correct_mapping = {

    # Clothing
    "T-shirt": "Clothing",
    "Shirt": "Clothing",
    "Shorts": "Clothing",
    "Hoodie": "Clothing",
    "Pants": "Clothing",
    "Socks": "Clothing",
    "Jeans": "Clothing",
    "Blouse": "Clothing",
    "Skirt": "Clothing",
    "Sweater": "Clothing",
    "Dress": "Clothing",

    # Accessories
    "Sunglasses": "Accessories",
    "Gloves": "Accessories",
    "Jewelry": "Accessories",
    "Hat": "Accessories",
    "Handbag": "Accessories",
    "Backpack": "Accessories",
    "Belt": "Accessories",
    "Scarf": "Accessories",
    "Bag": "Accessories",

    # Electronics
    "Laptop": "Electronics",
    "Phone": "Electronics",
    "Headphones": "Electronics",
    "Watch": "Electronics",

    # Footwear
    "Shoes": "Footwear",
    "Sandals": "Footwear",
    "Sneakers": "Footwear",
    "Boots": "Footwear",

    # Outerwear
    "Coat": "Outerwear",
    "Jacket": "Outerwear"
}

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories               [Sunglasses, Gloves, Jewelry, Hat, Handbag, Phone, Backpack, Belt, Bag, Headphones, Scarf, Watch, Shirt, Shoes, Laptop]
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone, Pants, Socks, Jeans, Bag, Blouse, Skirt, Sweater, Watch, Laptop, Dress, Headphones]
# Electronics                                                                                 [Laptop, Phone, Watch, Bag, Shoes, Shirt, Headphones]
# Footwear                                                                                                        [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                                                                          [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
df['category'] = df['Item Purchased'].map(correct_mapping)

# %%
df['category'] = df['Item Purchased'].map(correct_mapping)

# %%
df.groupby('category')['Item Purchased'].unique()
# Out:
# category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# category                    0
# dtype: int64

# %% [markdown]
# ## treating null values

# %% [markdown]
# size

# %%
df['Size'].unique()
# Out:
# array(['XL', 'M', 'L', 'S', nan], dtype=object)

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL]
# Clothing       [XL, M, S, L]
# Electronics            [nan]
# Footwear       [M, L, S, XL]
# Outerwear      [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.groupby('Item Purchased')['Size'].unique()
# Out:
# Item Purchased
# Backpack           [M, S, L, XL]
# Bag           [M, L, nan, XL, S]
# Belt               [M, S, XL, L]
# Blouse             [M, L, S, XL]
# Boots              [L, M, XL, S]
# Coat               [XL, M, S, L]
# Dress              [XL, M, L, S]
# Gloves             [L, M, S, XL]
# Handbag            [S, XL, M, L]
# Hat                [M, L, S, XL]
# Headphones    [S, M, nan, L, XL]
# Hoodie             [M, L, S, XL]
# Jacket             [L, S, M, XL]
# Jeans              [L, M, XL, S]
# Jewelry            [L, XL, M, S]
# Laptop        [nan, M, S, XL, L]
# Pants              [L, M, XL, S]
# Phone         [nan, L, S, M, XL]
# Sandals            [M, S, L, XL]
# Scarf              [M, L, S, XL]
# Shirt         [M, XL, L, S, nan]
# Shoes         [M, L, nan, XL, S]
# Shorts             [S, M, L, XL]
# Skirt              [S, L, M, XL]
# Sneakers           [S, M, L, XL]
# Socks              [M, XL, L, S]
# Sunglasses         [M, L, S, XL]
# Sweater            [M, S, L, XL]
# T-shirt            [XL, M, S, L]
# Watch         [nan, M, L, XL, S]
# Name: Size, dtype: object

# %%
df.loc[df['Category']=='Accessories','Size']="Free Size"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories      [Free Size]
# Clothing       [XL, M, S, L]
# Electronics            [nan]
# Footwear       [M, L, S, XL]
# Outerwear      [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.loc[df['Category']=='Electronics','Size']="not available"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories        [Free Size]
# Clothing         [XL, M, S, L]
# Electronics    [not available]
# Footwear         [M, L, S, XL]
# Outerwear        [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.loc[df['Category']=='Clothing','Size']="XL, M, S, L, nan"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics       [not available]
# Footwear            [M, L, S, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.loc[(df["Category"]=="Clothing") & (df["Size"].isnull()), "Size"] = df[df["Category"]=="Clothing"]["Size"].mode()[0]

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics       [not available]
# Footwear            [M, L, S, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# category                    0
# dtype: int64

# %% [markdown]
# ## treating null value of review rating

# %%
# mean of review ratings
df['Review Rating'].mean()
# Out:
# np.float64(3.668195100022477)

# %%
# median of review ratings
df['Review Rating'].median()
# Out:
# 3.7

# %%
# mode of review ratings
df['Review Rating'].mode()
# Out:
# 0    4.0
# Name: Review Rating, dtype: float64

# %%
df.groupby("Item Purchased")['Review Rating'].mean()
# Out:
# Item Purchased
# Backpack      3.758333
# Bag           3.168539
# Belt          3.762963
# Blouse        3.677647
# Boots         3.813194
# Coat          3.721875
# Dress         3.750000
# Gloves        3.862774
# Handbag       3.771975
# Hat           3.796753
# Headphones    3.075949
# Hoodie        3.716779
# Jacket        3.761446
# Jeans         3.651969
# Jewelry       3.761850
# Laptop        3.191176
# Pants         3.720833
# Phone         2.939024
# Sandals       3.837037
# Scarf         3.702564
# Shirt         3.427273
# Shoes         3.546154
# Shorts        3.722981
# Skirt         3.779747
# Sneakers      3.757931
# Socks         3.755063
# Sunglasses    3.745679
# Sweater       3.768712
# T-shirt       3.790541
# Watch         3.100000
# Name: Review Rating, dtype: float64

# %%
#Filling null values of Review Ratings with the mean of each Item Purchased
df['Review Rating']=df['Review Rating'].fillna(df.groupby('Item Purchased')['Review Rating'] .transform ('mean'))

# %%
df.head(5)
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location              Size   Color  Season  \
# 0                   68.0      California  XL, M, S, L, nan   Olive  Winter
# 1                   84.0  South Carolina         Free Size   White  Spring
# 2                   50.0         Montana  XL, M, S, L, nan   Black  Winter
# 3                   75.0        Illinois         Free Size     Red    Fall
# 4                   80.0         Alabama         Free Size  Yellow  Spring
#
#    Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0            3.2                  No        Standard               No
# 1            3.9                 Yes   Free Shipping              Yes
# 2            3.1                  No  2-Day Shipping               No
# 3            4.2                  No    Store Pickup               No
# 4            3.6                  No    Store Pickup               No
#
#    Previous Purchases Payment Method Frequency of Purchases     category
# 0                36.0           Cash                 Weekly     Clothing
# 1                20.0     Debit Card              Quarterly  Accessories
# 2                18.0           Cash                Monthly     Clothing
# 3                25.0           Cash               Annually  Accessories
# 4                17.0    Credit Card                 Weekly  Accessories

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# category                    0
# dtype: int64

# %% [markdown]
# ## previous purchase

# %%
# Filling Previous Purchases with Zero(0)
df['Previous Purchases']=df['Previous Purchases'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# category                    0
# dtype: int64

# %% [markdown]
# ## purchase amount

# %%
df.groupby("Item Purchased")['Purchase Amount (USD)'].mean()
# Out:
# Item Purchased
# Backpack       60.111111
# Bag           735.773625
# Belt           59.993902
# Blouse         60.802326
# Boots          62.616438
# Coat           57.851852
# Dress          62.168675
# Gloves         60.550000
# Handbag        57.987261
# Hat            60.787097
# Headphones    831.344565
# Hoodie         58.059603
# Jacket         56.777108
# Jeans          60.456693
# Jewelry        59.011494
# Laptop        805.502027
# Pants          59.005848
# Phone         734.477349
# Sandals        57.527607
# Scarf          61.157233
# Shirt         279.935608
# Shoes         276.343790
# Shorts         60.073620
# Skirt          59.723270
# Sneakers       59.551724
# Socks          58.188679
# Sunglasses     59.975610
# Sweater        57.638554
# T-shirt        63.093333
# Watch         685.231471
# Name: Purchase Amount (USD), dtype: float64

# %%
#Filling null values of Purchase Amount (USD) with the mean of each Item Purchased
df['Purchase Amount (USD)']=df['Purchase Amount (USD)'].fillna(df.groupby('Item Purchased')['Purchase Amount (USD)'] .transform ('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# category                  0
# dtype: int64

# %% [markdown]
# ### checking duplicate value

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df[df.duplicated()]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 886          2834   43  Female          Jeans     Clothing
# 1402         1621   25    Male            Hat  Accessories
# 1509          974   60    Male         Jacket    Outerwear
# 1600         2135   55    Male        Sandals     Footwear
# 1665         1846   51    Male        Sandals     Footwear
# 1797         3639   40  Female       Backpack  Accessories
# 1870         3456   49  Female        T-shirt     Clothing
# 2033         1812   42    Male           Belt  Accessories
# 2113         3040   59  Female         Blouse     Clothing
# 2226         1371   27    Male          Scarf  Accessories
# 2358         2977   30  Female           Coat    Outerwear
# 2447         2678   45  Female         Shorts     Clothing
# 2630          992   20    Male         Shorts     Clothing
# 2642         1566   58    Male     Sunglasses  Accessories
# 2739         2227   22    Male          Shirt     Clothing
# 2740         3487   51  Female         Shorts     Clothing
# 2800         2069   70    Male        Jewelry  Accessories
# 2905         2158   41    Male        Handbag  Accessories
# 2922         3334   55  Female          Jeans     Clothing
# 3036          258   20    Male        Handbag  Accessories
# 3065         3887   37  Female        Jewelry  Accessories
# 3185         1609   26    Male        Sandals     Footwear
# 3357         3091   29  Female          Shirt     Clothing
# 3390          603   37    Male          Shoes     Footwear
# 3538         1698   36    Male          Shirt     Clothing
# 3683         1209   20    Male          Boots     Footwear
# 3698          172   29    Male         Shorts     Clothing
# 3742          323   41    Male           Belt  Accessories
# 3810         2429   65    Male        T-shirt     Clothing
# 3843          615   68    Male        Jewelry  Accessories
# 3961         2558   70    Male         Shorts     Clothing
# 3987         3507   18  Female          Shirt     Clothing
# 4050         3287   45  Female         Jacket    Outerwear
# 4059          227   29    Male          Shoes     Footwear
# 4131         2642   25    Male     Sunglasses  Accessories
# 4183         1523   38    Male         Shorts     Clothing
# 4330         3716   63  Female     Sunglasses  Accessories
# 4390         3846   58  Female        Sweater     Clothing
# 4445         3644   53  Female          Scarf  Accessories
# 4445               Annually  Accessories
# 4468              Quarterly     Clothing
# 4513              Bi-Weekly  Accessories
# 4558                Monthly     Clothing
# 4595              Bi-Weekly     Footwear
# 4664         Every 3 Months  Accessories
# 4717         Every 3 Months     Clothing
# 4735              Bi-Weekly  Accessories
# 4841               Annually     Footwear
# 4887              Bi-Weekly     Clothing
# 4901                Monthly    Outerwear
# 5037                Monthly     Clothing

# %%
df[df['Customer ID']==227]
# Out:
#       Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 1569          227   29   Male          Shoes  Footwear                   74.0
# 4059          227   29   Male          Shoes  Footwear                   74.0
#
#      Location Size   Color  Season  Review Rating Subscription Status  \
# 1569    Texas    L  Violet  Spring            3.3                 Yes
# 4059    Texas    L  Violet  Spring            3.3                 Yes
#
#       Shipping Type Discount Applied  Previous Purchases Payment Method  \
# 1569  Free Shipping              Yes                 5.0         PayPal
# 4059  Free Shipping              Yes                 5.0         PayPal
#
#      Frequency of Purchases  category
# 1569                Monthly  Footwear
# 4059                Monthly  Footwear

# %%
# Deleting duplicate records
df=df.drop_duplicates(subset=['Customer ID'],keep='first')

# %%
len(df)
# Out:
# 5000

# %% [markdown]
# ## renamin the headers

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Previous Purchases', 'Payment Method',
#        'Frequency of Purchases', 'category'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(" ","_")
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'category'],
#       dtype='object')

# %%
#replacing purchase_amount_(usd) to purchase_amount
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'category'],
#       dtype='object')

# %%
df.head()
# Out:
#    customer_id  age  gender item_purchased     category  purchase_amount  \
# 0         2701   22  Female        T-shirt     Clothing             68.0
# 1          521   51    Male     Sunglasses  Accessories             84.0
# 2         3157   18  Female          Shirt     Clothing             50.0
# 3         1687   22    Male         Gloves  Accessories             75.0
# 4         2929   40  Female        Jewelry  Accessories             80.0
#
#          location              size   color  season  review_rating  \
# 0      California  XL, M, S, L, nan   Olive  Winter            3.2
# 1  South Carolina         Free Size   White  Spring            3.9
# 2         Montana  XL, M, S, L, nan   Black  Winter            3.1
# 3        Illinois         Free Size     Red    Fall            4.2
# 4         Alabama         Free Size  Yellow  Spring            3.6
#
#   subscription_status   shipping_type discount_applied  previous_purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   payment_method frequency_of_purchases     category
# 0           Cash                 Weekly     Clothing
# 1     Debit Card              Quarterly  Accessories
# 2           Cash                Monthly     Clothing
# 3           Cash               Annually  Accessories
# 4    Credit Card                 Weekly  Accessories

# %%
# !pip install pyodbc sqlalchemy
# Out:
# Collecting pyodbc
#   Downloading pyodbc-5.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.49)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.15.0)
# Downloading pyodbc-5.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.3/340.3 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.3.0

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Downloading mysql_connector_python-9.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (21.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 28.7 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.7.0

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
from google.colab import files

files.download('cleaned_data.csv')

# %%
len(df)
# Out:
# 5000

# %%
import csv

df.to_csv(
    'cleaned_data.csv',
    index=False,
    encoding='utf-8',
    quoting=csv.QUOTE_ALL
)

# %%
from google.colab import files

files.download('cleaned_data.csv')
